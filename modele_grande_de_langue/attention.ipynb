# %%
import torch

# %%
n=1 # input (X) dim
m=5 # Q,K,V dim

class SelfAtt(torch.nn.Module):
    def __init__(self):
        super(SelfAtt,self).__init__()
        wwq = torch.rand(n,m)
        wwk = torch.rand(n,m)
        wwv = torch.rand(n,m)
        self.wq = torch.nn.Parameter(wwq)
        self.wk = torch.nn.Parameter(wwk)
        self.wv = torch.nn.Parameter(wwv)
        self.fc = torch.nn.Linear(m,2)

    def forward(self,x):
        # x = (B=T,n)
        # print("x",x.shape)
        keys = torch.matmul(x,self.wk)
        # print("k",keys.shape)
        queries = torch.matmul(x,self.wq)
        # print("q",keys.shape)
        values = torch.matmul(x,self.wv)

        att = torch.matmul(queries,keys.transpose(0,1))
        # print("att",att.shape)
        s = torch.nn.Softmax(dim=1)
        natt = s(att)

        t = x.size(0)
        # print("natt",natt.shape)
        alpha = natt.unsqueeze(-1).expand(t,t,m)
        # print("alpha",alpha.shape)
        weighted = torch.mul(values,alpha)
        zatt = weighted.sum(dim=1)

        z = zatt.max(dim=0)[0]
        y = self.fc(z)
        return y

# %%
xs = []
ys = []

# create various types of artificial data to test self-attention
if True:
    for i in range(100):
        t = 1+int(torch.rand(1,).item()*10.)
        x = torch.rand(t+t,1)
        xs.append(x)
        if torch.rand(1,).item()<0.5:
            for j in range(t+t):
              x[j] += 1.
            ys.append(torch.LongTensor([0]))
        else:
            ys.append(torch.LongTensor([1]))
# else:
#     for i in range(100):
#         t = 1+int(torch.rand(1,).item()*10.)
#         x = torch.rand(t+t,1)
#         xs.append(x)
#         if torch.rand(1,).item()<0.5:
#             for j in range(t):
#               x[t+j] += 1.
#             ys.append(torch.LongTensor([0]))
#         else:
#             for j in range(t):
#               x[j] += 1.
#             ys.append(torch.LongTensor([1]))


mod=SelfAtt()

# %%
loss = torch.nn.CrossEntropyLoss()
opt = torch.optim.Adam(mod.parameters(),lr=0.01)
for ep in range(100):
    lo = 0.
    nok=0
    for i in range(len(xs)):
        opt.zero_grad()
        y = mod(xs[i])
        if y.max(dim=0)[1]==ys[i]:
            nok+=1
        y = y.view(1,-1)
        los = loss(y,ys[i])
        los.backward()
        opt.step()
        lo += los.item()
    acc = float(nok)/float(len(xs))
    print("ACC %f %f" % (lo,acc))
# Out:
# ACC 68.773468 0.470000
# ACC 54.251054 0.590000
# ACC 42.756206 0.920000
# ACC 34.011307 0.980000
# ACC 27.498585 1.000000
# ACC 22.635857 1.000000
# ACC 18.956837 1.000000
# ACC 16.126633 1.000000
# ACC 13.910533 1.000000
# ACC 12.144994 1.000000
# ACC 10.715654 1.000000
# ACC 9.541539 1.000000
# ACC 8.564362 1.000000
# ACC 7.741475 1.000000
# ACC 7.041159 1.000000
# ACC 6.439475 1.000000
# ACC 5.918088 1.000000
# ACC 5.462759 1.000000
# ACC 5.062307 1.000000
# ACC 4.707485 1.000000
# ACC 4.391748 1.000000
# ACC 4.111236 1.000000
# ACC 3.858865 1.000000
# ACC 3.630725 1.000000
# ACC 3.424672 1.000000
# ACC 3.237051 1.000000
# ACC 3.066055 1.000000
# ACC 2.909408 1.000000
# ACC 2.765727 1.000000
# ACC 2.633266 1.000000
# ACC 2.510808 1.000000
# ACC 2.397654 1.000000
# ACC 2.291503 1.000000
# ACC 2.194994 1.000000
# ACC 2.103688 1.000000
# ACC 2.017429 1.000000
# ACC 1.938613 1.000000
# ACC 1.863795 1.000000
# ACC 1.793773 1.000000
# ACC 1.727844 1.000000
# ACC 1.665646 1.000000
# ACC 1.607003 1.000000
# ACC 1.551597 1.000000
# ACC 1.499104 1.000000
# ACC 1.449291 1.000000
# ACC 1.402078 1.000000
# ACC 1.357291 1.000000
# ACC 1.314568 1.000000
# ACC 1.273892 1.000000
# ACC 1.235035 1.000000
# ACC 1.198465 1.000000
# ACC 1.162846 1.000000
# ACC 1.129502 1.000000
# ACC 1.097080 1.000000
# ACC 1.066362 1.000000
# ACC 1.036831 1.000000
# ACC 1.008419 1.000000
# ACC 0.981070 1.000000
# ACC 0.954727 1.000000
# ACC 0.929338 1.000000
# ACC 0.904847 1.000000
# ACC 0.881201 1.000000
# ACC 0.858338 1.000000
# ACC 0.836192 1.000000
# ACC 0.814688 1.000000
# ACC 0.793743 1.000000
# ACC 0.773274 1.000000
# ACC 0.753186 1.000000
# ACC 0.733411 1.000000
# ACC 0.713904 1.000000
# ACC 0.694681 1.000000
# ACC 0.675818 1.000000
# ACC 0.657445 1.000000
# ACC 0.639707 1.000000
# ACC 0.622711 1.000000
# ACC 0.606514 1.000000
# ACC 0.591114 1.000000
# ACC 0.576462 1.000000
# ACC 0.562493 1.000000
# ACC 0.549131 1.000000
# ACC 0.536309 1.000000
# ACC 0.523970 1.000000
# ACC 0.512062 1.000000
# ACC 0.500549 1.000000
# ACC 0.489396 1.000000
# ACC 0.478581 1.000000
# ACC 0.468082 1.000000
# ACC 0.457882 1.000000
# ACC 0.447967 1.000000
# ACC 0.438325 1.000000
# ACC 0.428945 1.000000
# ACC 0.419818 1.000000
# ACC 0.410934 1.000000
# ACC 0.402288 1.000000
# ACC 0.393868 1.000000
# ACC 0.385671 1.000000
# ACC 0.377687 1.000000
# ACC 0.369911 1.000000
# ACC 0.362336 1.000000
# ACC 0.354956 1.000000
