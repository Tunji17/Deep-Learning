# %% [markdown]
# # Lab 5: Text-to-Speech (TTS)

# %% [markdown]
# In this lab, first, we will study how to train a neural-based TTS model Tacotron 2 with  using SpeechBrain on the LJSpeech corpus.
#
#
# #### <span style="color:green"> Text-to-Speech (TTS) with Tacotron2 trained on LJSpeech (with a pretrained model) </span>
#
#
# The pre-trained model takes in input a short text and produces a spectrogram in output. One can get the final waveform by applying a vocoder (e.g., HiFIGAN) on top of the generated spectrogram.
#
# #### Perform TTS with a pretrained model

# %%
import os
import torch
import torchaudio
import IPython
import matplotlib.pyplot as plt
from speechbrain.inference.TTS import Tacotron2
from speechbrain.inference.vocoders import HIFIGAN

# %%
torch.random.manual_seed(0)
device = "cuda" if torch.cuda.is_available() else "cpu"

print(torch.__version__)
print(torchaudio.__version__)
print(device)
# Out:
# 2.2.1
# 2.2.1
# cpu

# %%
# Intialize TTS (tacotron2) and Vocoder (HiFIGAN)
tacotron2 = Tacotron2.from_hparams(source="speechbrain/tts-tacotron2-ljspeech", savedir="tmpdir_tts")
hifi_gan = HIFIGAN.from_hparams(source="speechbrain/tts-hifigan-ljspeech", savedir="tmpdir_vocoder")

# Running the TTS
mel_output, mel_length, alignment = tacotron2.encode_text("Hello!")

# Running Vocoder (spectrogram-to-waveform)
waveforms = hifi_gan.decode_batch(mel_output)

# Save the waverform
torchaudio.save('example_TTS.wav', waveforms.squeeze(1), 22050)

IPython.display.Audio(data=waveforms.squeeze(1), rate=22050)
# Out:
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Fetching from HuggingFace Hub 'speechbrain/tts-tacotron2-ljspeech' if not cached
# INFO:speechbrain.utils.fetching:Fetch custom.py: Fetching from HuggingFace Hub 'speechbrain/tts-tacotron2-ljspeech' if not cached
# INFO:speechbrain.utils.fetching:Fetch model.ckpt: Fetching from HuggingFace Hub 'speechbrain/tts-tacotron2-ljspeech' if not cached
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: model
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-ljspeech' if not cached
# INFO:speechbrain.utils.fetching:Fetch custom.py: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-ljspeech' if not cached
# /Users/tunji/.local/share/virtualenvs/nn_speech_recognition-qgr9tgLb/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# INFO:speechbrain.utils.fetching:Fetch generator.ckpt: Fetching from HuggingFace Hub 'speechbrain/tts-hifigan-ljspeech' if not cached
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: generator
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### <span style="color:green"> Train Text-to-Speech (TTS) </span>
#
# The model is trained with SpeechBrain (on a small subset of the origonal corpus)
#
# Complete 3 steps:

# %% [markdown]
# 1. ##### Reduce number of files in the train dataset:

# %%
! mv LJSpeech-1.1/metadata.csv LJSpeech-1.1/metadata_original.csv
! head -n 128 LJSpeech-1.1/metadata_original.csv > LJSpeech-1.1/metadata.csv

# %% [markdown]
# 2. ##### Change params in train.yaml:
#
#     Path: speechbrain/recipes/LJSpeech/TTS/tacotron2/hparams/train.yaml
#
#         - epochs: 8
#         - keep_checkpoint_interval: 1
#         - batch_size: 8
#         - num_workers: 0

# %% [markdown]
# 3. ##### Run training:

# %% [markdown]
# <span style="color:red"> **Exercise:**</span>
# <span style="color:orange"> **Speech-to-text training**</span>
#
# The training of the full model is too long, and in this excercise,  we will try only several epochs of traing on the subset of the traing corpus in order to speed up the experiment:
#
# 1. Train 8 (or more) epochs:
#  - keep_checkpoint_interval: 1
#  - batch_size: 8
#  - 128 files of the LJSpeech
#  - num_workers: 0
#
# 2. Report logs with loss values on train and validation dataset. Which losses were used in the training?
#
# 3. Do you observe overfitting? Please explain your answer.

# %%
! python \
  speechbrain/recipes/LJSpeech/TTS/tacotron2/train.py \
  --device=cpu \
  --max_grad_norm=1.0 \
  --data_folder=LJSpeech-1.1 \
  speechbrain/recipes/LJSpeech/TTS/tacotron2/hparams/train.yaml
# Out:
# INFO:speechbrain.utils.quirks:Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# INFO:speechbrain.utils.quirks:Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# INFO:speechbrain.utils.seed:Setting seed to 1234
# speechbrain.utils.quirks - Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# speechbrain.utils.quirks - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: ./results/tacotron2/1234
# ljspeech_prepare - Skipping preparation, completed in previous run.
# speechbrain.core - Gradscaler enabled: False. Using precision: fp32.
# speechbrain.core - Tacotron2Brain Model Statistics:
# * Total Number of Trainable Parameters: 28.2M
# * Total Number of Parameters: 28.2M
# * Trainable Parameters represent 100.0000% of the total size.
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
#   0%|                                                    | 0/15 [00:00<?, ?it/s]/Users/tunji/.local/share/virtualenvs/nn_speech_recognition-qgr9tgLb/lib/python3.12/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3550.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100%|██████████████████████████| 15/15 [08:11<00:00, 32.79s/it, train_loss=12.1]
# 100%|█████████████████████████████████████████████| 2/2 [00:15<00:00,  7.95s/it]
# speechbrain.utils.train_logger - Epoch: 1, lr: 1.00e-03 - train loss: 4.25, train mel_loss: 4.09, train gate_loss: 1.26e-02, train attn_loss: 1.43e-01, train attn_weight: 46.65 - valid loss: 6.82, valid mel_loss: 6.69, valid gate_loss: 1.05e-02, valid attn_loss: 1.21e-01, valid attn_weight: 46.65
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/tacotron2/1234/save/CKPT+2024-12-18+14-15-51+00
# speechbrain.utils.epoch_loop - Going into epoch 2
# 100%|██████████████████████████| 15/15 [08:27<00:00, 33.86s/it, train_loss=4.12]
# 100%|█████████████████████████████████████████████| 2/2 [00:15<00:00,  7.64s/it]
# speechbrain.utils.train_logger - Epoch: 2, lr: 1.00e-03 - train loss: 4.07, train mel_loss: 3.96, train gate_loss: 1.09e-02, train attn_loss: 9.70e-02, train attn_weight: 43.53 - valid loss: 4.63, valid mel_loss: 4.52, valid gate_loss: 1.10e-02, valid attn_loss: 1.04e-01, valid attn_weight: 43.53
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/tacotron2/1234/save/CKPT+2024-12-18+14-24-36+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# 100%|██████████████████████████| 15/15 [10:38<00:00, 42.55s/it, train_loss=3.87]
# 100%|█████████████████████████████████████████████| 2/2 [00:11<00:00,  5.81s/it]
# speechbrain.utils.train_logger - Epoch: 3, lr: 1.00e-03 - train loss: 3.68, train mel_loss: 3.59, train gate_loss: 1.05e-02, train attn_loss: 7.74e-02, train attn_weight: 40.61 - valid loss: 4.22, valid mel_loss: 4.13, valid gate_loss: 8.87e-03, valid attn_loss: 8.60e-02, valid attn_weight: 40.61
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/tacotron2/1234/save/CKPT+2024-12-18+14-35-33+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# 100%|██████████████████████████| 15/15 [07:48<00:00, 31.25s/it, train_loss=3.64]
# 100%|█████████████████████████████████████████████| 2/2 [00:14<00:00,  7.24s/it]
# speechbrain.utils.train_logger - Epoch: 4, lr: 1.00e-03 - train loss: 3.45, train mel_loss: 3.36, train gate_loss: 9.08e-03, train attn_loss: 7.56e-02, train attn_weight: 37.89 - valid loss: 3.75, valid mel_loss: 3.67, valid gate_loss: 7.95e-03, valid attn_loss: 7.24e-02, valid attn_weight: 37.89
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/tacotron2/1234/save/CKPT+2024-12-18+14-43-43+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# 100%|██████████████████████████| 15/15 [08:31<00:00, 34.09s/it, train_loss=3.32]
# 100%|█████████████████████████████████████████████| 2/2 [00:16<00:00,  8.28s/it]
# speechbrain.utils.train_logger - Epoch: 5, lr: 1.00e-03 - train loss: 3.05, train mel_loss: 2.98, train gate_loss: 7.47e-03, train attn_loss: 6.42e-02, train attn_weight: 35.36 - valid loss: 2.98, valid mel_loss: 2.92, valid gate_loss: 7.42e-03, valid attn_loss: 5.78e-02, valid attn_weight: 35.36
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/tacotron2/1234/save/CKPT+2024-12-18+14-52-38+00
# speechbrain.utils.epoch_loop - Going into epoch 6
# 100%|███████████████████████████| 15/15 [10:36<00:00, 42.46s/it, train_loss=2.8]
# 100%|█████████████████████████████████████████████| 2/2 [00:14<00:00,  7.07s/it]
# speechbrain.utils.train_logger - Epoch: 6, lr: 1.00e-03 - train loss: 2.65, train mel_loss: 2.58, train gate_loss: 7.36e-03, train attn_loss: 5.66e-02, train attn_weight: 32.99 - valid loss: 2.50, valid mel_loss: 2.45, valid gate_loss: 7.59e-03, valid attn_loss: 4.39e-02, valid attn_weight: 32.99
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/tacotron2/1234/save/CKPT+2024-12-18+15-03-37+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# 100%|██████████████████████████| 15/15 [07:59<00:00, 31.95s/it, train_loss=2.52]
# 100%|█████████████████████████████████████████████| 2/2 [00:14<00:00,  7.29s/it]
# speechbrain.utils.train_logger - Epoch: 7, lr: 1.00e-03 - train loss: 2.47, train mel_loss: 2.42, train gate_loss: 7.29e-03, train attn_loss: 3.84e-02, train attn_weight: 30.78 - valid loss: 2.35, valid mel_loss: 2.31, valid gate_loss: 7.24e-03, valid attn_loss: 3.35e-02, valid attn_weight: 30.78
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/tacotron2/1234/save/CKPT+2024-12-18+15-11-59+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# 100%|██████████████████████████| 15/15 [08:12<00:00, 32.82s/it, train_loss=2.38]
# 100%|█████████████████████████████████████████████| 2/2 [00:16<00:00,  8.02s/it]
# speechbrain.utils.train_logger - Epoch: 8, lr: 1.00e-03 - train loss: 2.32, train mel_loss: 2.28, train gate_loss: 9.31e-03, train attn_loss: 2.93e-02, train attn_weight: 28.72 - valid loss: 2.29, valid mel_loss: 2.25, valid gate_loss: 6.82e-03, valid attn_loss: 2.97e-02, valid attn_weight: 28.72
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/tacotron2/1234/save/CKPT+2024-12-18+15-20-35+00

# %%
# Comment: No i didn't observe overfitting in the training process.
# The model was trained for 8 epochs and the training loss was decreasing with each epoch.
# The validation loss was also decreasing with each epoch
